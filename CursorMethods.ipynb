# %% [markdown]
# <a href="https://colab.research.google.com/github/thanmai09/mongodb-commands/blob/main/CursorMethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Microsoft Windows [Version 10.0.19045.6466]
(c) Microsoft Corporation. All rights reserved.

C:\Users\LENOVO>mongod
{"t":{"$date":"2026-01-28T21:20:46.451+05:30"},"s":"I",  "c":"NETWORK",  "id":4915701, "ctx":"thread1","msg":"Initialized wire specification","attr":{"spec":{"incomingExternalClient":{"minWireVersion":0,"maxWireVersion":21},"incomingInternalClient":{"minWireVersion":0,"maxWireVersion":21},"outgoing":{"minWireVersion":6,"maxWireVersion":21},"isInternalClient":true}}}
{"t":{"$date":"2026-01-28T21:20:46.453+05:30"},"s":"I",  "c":"CONTROL",  "id":23285,   "ctx":"thread1","msg":"Automatically disabling TLS 1.0, to force-enable TLS 1.0 specify --sslDisabledProtocols 'none'"}
{"t":{"$date":"2026-01-28T21:20:46.469+05:30"},"s":"I",  "c":"NETWORK",  "id":4648602, "ctx":"thread1","msg":"Implicit TCP FastOpen in use."}
{"t":{"$date":"2026-01-28T21:20:46.497+05:30"},"s":"I",  "c":"REPL",     "id":5123008, "ctx":"thread1","msg":"Successfully registered PrimaryOnlyService","attr":{"service":"TenantMigrationDonorService","namespace":"config.tenantMigrationDonors"}}
{"t":{"$date":"2026-01-28T21:20:46.497+05:30"},"s":"I",  "c":"REPL",     "id":5123008, "ctx":"thread1","msg":"Successfully registered PrimaryOnlyService","attr":{"service":"TenantMigrationRecipientService","namespace":"config.tenantMigrationRecipients"}}
{"t":{"$date":"2026-01-28T21:20:46.497+05:30"},"s":"I",  "c":"CONTROL",  "id":5945603, "ctx":"thread1","msg":"Multi threading initialized"}
{"t":{"$date":"2026-01-28T21:20:46.498+05:30"},"s":"I",  "c":"TENANT_M", "id":7091600, "ctx":"thread1","msg":"Starting TenantMigrationAccessBlockerRegistry"}
{"t":{"$date":"2026-01-28T21:20:46.500+05:30"},"s":"I",  "c":"CONTROL",  "id":4615611, "ctx":"initandlisten","msg":"MongoDB starting","attr":{"pid":4128,"port":27017,"dbPath":"C:/data/db/","architecture":"64-bit","host":"DESKTOP-M7L5VQ3"}}
{"t":{"$date":"2026-01-28T21:20:46.502+05:30"},"s":"I",  "c":"CONTROL",  "id":23398,   "ctx":"initandlisten","msg":"Target operating system minimum version","attr":{"targetMinOS":"Windows 7/Windows Server 2008 R2"}}
{"t":{"$date":"2026-01-28T21:20:46.502+05:30"},"s":"I",  "c":"CONTROL",  "id":23403,   "ctx":"initandlisten","msg":"Build Info","attr":{"buildInfo":{"version":"7.0.28","gitVersion":"cfc346c59d2cc3dbc903507fc642e22e3097f362","modules":[],"allocator":"tcmalloc","environment":{"distmod":"windows","distarch":"x86_64","target_arch":"x86_64"}}}}
{"t":{"$date":"2026-01-28T21:20:46.503+05:30"},"s":"I",  "c":"CONTROL",  "id":51765,   "ctx":"initandlisten","msg":"Operating System","attr":{"os":{"name":"Microsoft Windows 10","version":"10.0 (build 19045)"}}}
{"t":{"$date":"2026-01-28T21:20:46.503+05:30"},"s":"I",  "c":"CONTROL",  "id":21951,   "ctx":"initandlisten","msg":"Options set by command line","attr":{"options":{}}}
{"t":{"$date":"2026-01-28T21:20:46.512+05:30"},"s":"E",  "c":"CONTROL",  "id":20557,   "ctx":"initandlisten","msg":"DBException in initAndListen, terminating","attr":{"error":"NonExistentPath: Data directory C:\\data\\db\\ not found. Create the missing directory or specify another path using (1) the --dbpath command line option, or (2) by adding the 'storage.dbPath' option in the configuration file."}}
{"t":{"$date":"2026-01-28T21:20:46.513+05:30"},"s":"I",  "c":"REPL",     "id":4784900, "ctx":"initandlisten","msg":"Stepping down the ReplicationCoordinator for shutdown","attr":{"waitTimeMillis":15000}}
{"t":{"$date":"2026-01-28T21:20:46.517+05:30"},"s":"I",  "c":"REPL",     "id":4794602, "ctx":"initandlisten","msg":"Attempting to enter quiesce mode"}
{"t":{"$date":"2026-01-28T21:20:46.518+05:30"},"s":"I",  "c":"-",        "id":6371601, "ctx":"initandlisten","msg":"Shutting down the FLE Crud thread pool"}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"COMMAND",  "id":4784901, "ctx":"initandlisten","msg":"Shutting down the MirrorMaestro"}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"SHARDING", "id":4784902, "ctx":"initandlisten","msg":"Shutting down the WaitForMajorityService"}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"NETWORK",  "id":20562,   "ctx":"initandlisten","msg":"Shutdown: going to close listening sockets"}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"NETWORK",  "id":4784905, "ctx":"initandlisten","msg":"Shutting down the global connection pool"}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"CONTROL",  "id":4784906, "ctx":"initandlisten","msg":"Shutting down the FlowControlTicketholder"}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"-",        "id":20520,   "ctx":"initandlisten","msg":"Stopping further Flow Control ticket acquisitions."}
{"t":{"$date":"2026-01-28T21:20:46.519+05:30"},"s":"I",  "c":"NETWORK",  "id":4784918, "ctx":"initandlisten","msg":"Shutting down the ReplicaSetMonitor"}
{"t":{"$date":"2026-01-28T21:20:46.520+05:30"},"s":"I",  "c":"SHARDING", "id":4784921, "ctx":"initandlisten","msg":"Shutting down the MigrationUtilExecutor"}
{"t":{"$date":"2026-01-28T21:20:46.521+05:30"},"s":"I",  "c":"ASIO",     "id":22582,   "ctx":"MigrationUtil-TaskExecutor","msg":"Killing all outstanding egress activity."}
{"t":{"$date":"2026-01-28T21:20:46.523+05:30"},"s":"I",  "c":"COMMAND",  "id":4784923, "ctx":"initandlisten","msg":"Shutting down the ServiceEntryPoint"}
{"t":{"$date":"2026-01-28T21:20:46.524+05:30"},"s":"I",  "c":"CONTROL",  "id":4784928, "ctx":"initandlisten","msg":"Shutting down the TTL monitor"}
{"t":{"$date":"2026-01-28T21:20:46.524+05:30"},"s":"I",  "c":"CONTROL",  "id":6278511, "ctx":"initandlisten","msg":"Shutting down the Change Stream Expired Pre-images Remover"}
{"t":{"$date":"2026-01-28T21:20:46.524+05:30"},"s":"I",  "c":"CONTROL",  "id":4784929, "ctx":"initandlisten","msg":"Acquiring the global lock for shutdown"}
{"t":{"$date":"2026-01-28T21:20:46.524+05:30"},"s":"I",  "c":"-",        "id":4784931, "ctx":"initandlisten","msg":"Dropping the scope cache for shutdown"}
{"t":{"$date":"2026-01-28T21:20:46.524+05:30"},"s":"I",  "c":"CONTROL",  "id":20565,   "ctx":"initandlisten","msg":"Now exiting"}
{"t":{"$date":"2026-01-28T21:20:46.525+05:30"},"s":"I",  "c":"CONTROL",  "id":8423404, "ctx":"initandlisten","msg":"mongod shutdown complete","attr":{"Summary of time elapsed":{"Statistics":{"Enter terminal shutdown":"0 ms","Step down the replication coordinator for shutdown":"5 ms","Time spent in quiesce mode":"0 ms","Shut down FLE Crud subsystem":"1 ms","Shut down MirrorMaestro":"1 ms","Shut down WaitForMajorityService":"0 ms","Shut down the transport layer":"0 ms","Shut down the global connection pool":"0 ms","Shut down the flow control ticket holder":"0 ms","Shut down the replica set monitor":"0 ms","Shut down the migration util executor":"1 ms","Shut down the TTL monitor":"1 ms","Shut down expired pre-images and documents removers":"0 ms","Wait for the oplog cap maintainer thread to stop":"0 ms","Shut down full-time data capture":"0 ms","shutdownTask total elapsed time":"12 ms"}}}}
{"t":{"$date":"2026-01-28T21:20:46.526+05:30"},"s":"I",  "c":"CONTROL",  "id":23138,   "ctx":"initandlisten","msg":"Shutting down","attr":{"exitCode":100}}

C:\Users\LENOVO>mongosh
Current Mongosh Log ID: 697a3061c155f141a41e2620
Connecting to:          mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.5.10
Using MongoDB:          7.0.28
Using Mongosh:          2.5.10
mongosh 2.6.0 is available for download: https://www.mongodb.com/try/download/shell

For mongosh info see: https://www.mongodb.com/docs/mongodb-shell/

------
   The server generated these startup warnings when booting
   2026-01-03T12:40:57.564+05:30: Access control is not enabled for the database. Read and write access to data and configuration is unrestricted
------

test> use test
already on db test
test> db.emp.find()
[
  {
    _id: ObjectId('694e86da48b36af6011e2623'),
    ename: 'cvbnm',
    empid: 99,
    sal: 9000
  },
  {
    _id: ObjectId('694e887448b36af6011e2624'),
    ename: 'ijhg',
    empid: 978,
    sal: 9800
  },
  {
    _id: ObjectId('694e887448b36af6011e2625'),
    ename: 'uytrsdfgh',
    empid: 97,
    sal: 5000
  },
  {
    _id: ObjectId('694e887448b36af6011e2626'),
    ename: 'thannu',
    empid: 37,
    sal: 2000
  },
  {
    _id: ObjectId('694e896c48b36af6011e2627'),
    ename: 'bbb',
    empid: 0,
    sal: 10
  },
  {
    _id: ObjectId('694e89ca48b36af6011e2628'),
    ename: 'iuytrsgh',
    empid: 39999,
    sal: 899
  },
  {
    _id: ObjectId('694e8b3548b36af6011e2629'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b4d48b36af6011e262a'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b8248b36af6011e262b'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b8448b36af6011e262c'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b9448b36af6011e262d'),
    ename: 'krishna',
    sal: 22,
    _empid: 99
  },
  { _id: 99, ename: 'krishna', sal: 22 },
  {
    _id: ObjectId('694e8f6048b36af6011e262e'),
    ename: 'john',
    empid: 101,
    sal: 9000
  },
  {
    _id: ObjectId('694e8f6048b36af6011e262f'),
    ename: 'jane',
    empid: 102,
    sal: 9500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2630'),
    ename: 'doe',
    empid: 103,
    sal: 8500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2631'),
    ename: 'smith',
    empid: 104,
    sal: 9200
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2632'),
    ename: 'alice',
    empid: 105,
    sal: 9800
  },
  {
    _id: ObjectId('696bc3b425b9d854a11e2621'),
    ename: 'Ravi',
    empid: 106,
    sal: 9900
  },
  {
    _id: ObjectId('696bc3f825b9d854a11e2622'),
    ename: 'Sai',
    empid: 107,
    sal: 8000
  },
  { _id: 300, ename: 'Ramu', sal: 10000 }
]
test> var result = db.emp.find()

test> result
[
  {
    _id: ObjectId('694e86da48b36af6011e2623'),
    ename: 'cvbnm',
    empid: 99,
    sal: 9000
  },
  {
    _id: ObjectId('694e887448b36af6011e2624'),
    ename: 'ijhg',
    empid: 978,
    sal: 9800
  },
  {
    _id: ObjectId('694e887448b36af6011e2625'),
    ename: 'uytrsdfgh',
    empid: 97,
    sal: 5000
  },
  {
    _id: ObjectId('694e887448b36af6011e2626'),
    ename: 'thannu',
    empid: 37,
    sal: 2000
  },
  {
    _id: ObjectId('694e896c48b36af6011e2627'),
    ename: 'bbb',
    empid: 0,
    sal: 10
  },
  {
    _id: ObjectId('694e89ca48b36af6011e2628'),
    ename: 'iuytrsgh',
    empid: 39999,
    sal: 899
  },
  {
    _id: ObjectId('694e8b3548b36af6011e2629'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b4d48b36af6011e262a'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b8248b36af6011e262b'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b8448b36af6011e262c'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b9448b36af6011e262d'),
    ename: 'krishna',
    sal: 22,
    _empid: 99
  },
  { _id: 99, ename: 'krishna', sal: 22 },
  {
    _id: ObjectId('694e8f6048b36af6011e262e'),
    ename: 'john',
    empid: 101,
    sal: 9000
  },
  {
    _id: ObjectId('694e8f6048b36af6011e262f'),
    ename: 'jane',
    empid: 102,
    sal: 9500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2630'),
    ename: 'doe',
    empid: 103,
    sal: 8500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2631'),
    ename: 'smith',
    empid: 104,
    sal: 9200
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2632'),
    ename: 'alice',
    empid: 105,
    sal: 9800
  },
  {
    _id: ObjectId('696bc3b425b9d854a11e2621'),
    ename: 'Ravi',
    empid: 106,
    sal: 9900
  },
  {
    _id: ObjectId('696bc3f825b9d854a11e2622'),
    ename: 'Sai',
    empid: 107,
    sal: 8000
  },
  { _id: 300, ename: 'Ramu', sal: 10000 }
]
test> result.next()
null
test> db.emp.find().next()
{
  _id: ObjectId('694e86da48b36af6011e2623'),
  ename: 'cvbnm',
  empid: 99,
  sal: 9000
}
test> db.emp.find().next()
{
  _id: ObjectId('694e86da48b36af6011e2623'),
  ename: 'cvbnm',
  empid: 99,
  sal: 9000
}
test> var result = db.emp.find()

test> result
[
  {
    _id: ObjectId('694e86da48b36af6011e2623'),
    ename: 'cvbnm',
    empid: 99,
    sal: 9000
  },
  {
    _id: ObjectId('694e887448b36af6011e2624'),
    ename: 'ijhg',
    empid: 978,
    sal: 9800
  },
  {
    _id: ObjectId('694e887448b36af6011e2625'),
    ename: 'uytrsdfgh',
    empid: 97,
    sal: 5000
  },
  {
    _id: ObjectId('694e887448b36af6011e2626'),
    ename: 'thannu',
    empid: 37,
    sal: 2000
  },
  {
    _id: ObjectId('694e896c48b36af6011e2627'),
    ename: 'bbb',
    empid: 0,
    sal: 10
  },
  {
    _id: ObjectId('694e89ca48b36af6011e2628'),
    ename: 'iuytrsgh',
    empid: 39999,
    sal: 899
  },
  {
    _id: ObjectId('694e8b3548b36af6011e2629'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b4d48b36af6011e262a'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b8248b36af6011e262b'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b8448b36af6011e262c'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b9448b36af6011e262d'),
    ename: 'krishna',
    sal: 22,
    _empid: 99
  },
  { _id: 99, ename: 'krishna', sal: 22 },
  {
    _id: ObjectId('694e8f6048b36af6011e262e'),
    ename: 'john',
    empid: 101,
    sal: 9000
  },
  {
    _id: ObjectId('694e8f6048b36af6011e262f'),
    ename: 'jane',
    empid: 102,
    sal: 9500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2630'),
    ename: 'doe',
    empid: 103,
    sal: 8500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2631'),
    ename: 'smith',
    empid: 104,
    sal: 9200
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2632'),
    ename: 'alice',
    empid: 105,
    sal: 9800
  },
  {
    _id: ObjectId('696bc3b425b9d854a11e2621'),
    ename: 'Ravi',
    empid: 106,
    sal: 9900
  },
  {
    _id: ObjectId('696bc3f825b9d854a11e2622'),
    ename: 'Sai',
    empid: 107,
    sal: 8000
  },
  { _id: 300, ename: 'Ramu', sal: 10000 }
]
test> result.next()
null
test> result.next()
null
test> result.hasNext()
false
test> var result = db.emp.find()

test> result.hasNext()
true
test> while (result.hasNext())
... {
... print(result.next())
...
... }
{
  _id: ObjectId('694e86da48b36af6011e2623'),
  ename: 'cvbnm',
  empid: 99,
  sal: 9000
}
{
  _id: ObjectId('694e887448b36af6011e2624'),
  ename: 'ijhg',
  empid: 978,
  sal: 9800
}
{
  _id: ObjectId('694e887448b36af6011e2625'),
  ename: 'uytrsdfgh',
  empid: 97,
  sal: 5000
}
{
  _id: ObjectId('694e887448b36af6011e2626'),
  ename: 'thannu',
  empid: 37,
  sal: 2000
}
{
  _id: ObjectId('694e896c48b36af6011e2627'),
  ename: 'bbb',
  empid: 0,
  sal: 10
}
{
  _id: ObjectId('694e89ca48b36af6011e2628'),
  ename: 'iuytrsgh',
  empid: 39999,
  sal: 899
}
{
  _id: ObjectId('694e8b3548b36af6011e2629'),
  ename: 'krishna',
  sal: 3222,
  empid: 99
}
{
  _id: ObjectId('694e8b4d48b36af6011e262a'),
  ename: 'krishna',
  sal: 3222,
  empid: 99
}
{
  _id: ObjectId('694e8b8248b36af6011e262b'),
  ename: 'krishna',
  sal: 3222,
  _empid: 99
}
{
  _id: ObjectId('694e8b8448b36af6011e262c'),
  ename: 'krishna',
  sal: 3222,
  _empid: 99
}
{
  _id: ObjectId('694e8b9448b36af6011e262d'),
  ename: 'krishna',
  sal: 22,
  _empid: 99
}
{ _id: 99, ename: 'krishna', sal: 22 }
{
  _id: ObjectId('694e8f6048b36af6011e262e'),
  ename: 'john',
  empid: 101,
  sal: 9000
}
{
  _id: ObjectId('694e8f6048b36af6011e262f'),
  ename: 'jane',
  empid: 102,
  sal: 9500
}
{
  _id: ObjectId('694e8f6048b36af6011e2630'),
  ename: 'doe',
  empid: 103,
  sal: 8500
}
{
  _id: ObjectId('694e8f6048b36af6011e2631'),
  ename: 'smith',
  empid: 104,
  sal: 9200
}
{
  _id: ObjectId('694e8f6048b36af6011e2632'),
  ename: 'alice',
  empid: 105,
  sal: 9800
}
{
  _id: ObjectId('696bc3b425b9d854a11e2621'),
  ename: 'Ravi',
  empid: 106,
  sal: 9900
}
{
  _id: ObjectId('696bc3f825b9d854a11e2622'),
  ename: 'Sai',
  empid: 107,
  sal: 8000
}
{ _id: 300, ename: 'Ramu', sal: 10000 }

test> db.emp.find()
[
  {
    _id: ObjectId('694e86da48b36af6011e2623'),
    ename: 'cvbnm',
    empid: 99,
    sal: 9000
  },
  {
    _id: ObjectId('694e887448b36af6011e2624'),
    ename: 'ijhg',
    empid: 978,
    sal: 9800
  },
  {
    _id: ObjectId('694e887448b36af6011e2625'),
    ename: 'uytrsdfgh',
    empid: 97,
    sal: 5000
  },
  {
    _id: ObjectId('694e887448b36af6011e2626'),
    ename: 'thannu',
    empid: 37,
    sal: 2000
  },
  {
    _id: ObjectId('694e896c48b36af6011e2627'),
    ename: 'bbb',
    empid: 0,
    sal: 10
  },
  {
    _id: ObjectId('694e89ca48b36af6011e2628'),
    ename: 'iuytrsgh',
    empid: 39999,
    sal: 899
  },
  {
    _id: ObjectId('694e8b3548b36af6011e2629'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b4d48b36af6011e262a'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b8248b36af6011e262b'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b8448b36af6011e262c'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b9448b36af6011e262d'),
    ename: 'krishna',
    sal: 22,
    _empid: 99
  },
  { _id: 99, ename: 'krishna', sal: 22 },
  {
    _id: ObjectId('694e8f6048b36af6011e262e'),
    ename: 'john',
    empid: 101,
    sal: 9000
  },
  {
    _id: ObjectId('694e8f6048b36af6011e262f'),
    ename: 'jane',
    empid: 102,
    sal: 9500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2630'),
    ename: 'doe',
    empid: 103,
    sal: 8500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2631'),
    ename: 'smith',
    empid: 104,
    sal: 9200
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2632'),
    ename: 'alice',
    empid: 105,
    sal: 9800
  },
  {
    _id: ObjectId('696bc3b425b9d854a11e2621'),
    ename: 'Ravi',
    empid: 106,
    sal: 9900
  },
  {
    _id: ObjectId('696bc3f825b9d854a11e2622'),
    ename: 'Sai',
    empid: 107,
    sal: 8000
  },
  { _id: 300, ename: 'Ramu', sal: 10000 }
]
test> DBQuery.shallBatchSize=2
2
test> DBQuery.displayBatchSize=2
2
test> db.emp.find()

[
  {
    _id: ObjectId('694e86da48b36af6011e2623'),
    ename: 'cvbnm',
    empid: 99,
    sal: 9000
  },
  {
    _id: ObjectId('694e887448b36af6011e2624'),
    ename: 'ijhg',
    empid: 978,
    sal: 9800
  },
  {
    _id: ObjectId('694e887448b36af6011e2625'),
    ename: 'uytrsdfgh',
    empid: 97,
    sal: 5000
  },
  {
    _id: ObjectId('694e887448b36af6011e2626'),
    ename: 'thannu',
    empid: 37,
    sal: 2000
  },
  {
    _id: ObjectId('694e896c48b36af6011e2627'),
    ename: 'bbb',
    empid: 0,
    sal: 10
  },
  {
    _id: ObjectId('694e89ca48b36af6011e2628'),
    ename: 'iuytrsgh',
    empid: 39999,
    sal: 899
  },
  {
    _id: ObjectId('694e8b3548b36af6011e2629'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b4d48b36af6011e262a'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b8248b36af6011e262b'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b8448b36af6011e262c'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b9448b36af6011e262d'),
    ename: 'krishna',
    sal: 22,
    _empid: 99
  },
  { _id: 99, ename: 'krishna', sal: 22 },
  {
    _id: ObjectId('694e8f6048b36af6011e262e'),
    ename: 'john',
    empid: 101,
    sal: 9000
  },
  {
    _id: ObjectId('694e8f6048b36af6011e262f'),
    ename: 'jane',
    empid: 102,
    sal: 9500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2630'),
    ename: 'doe',
    empid: 103,
    sal: 8500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2631'),
    ename: 'smith',
    empid: 104,
    sal: 9200
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2632'),
    ename: 'alice',
    empid: 105,
    sal: 9800
  },
  {
    _id: ObjectId('696bc3b425b9d854a11e2621'),
    ename: 'Ravi',
    empid: 106,
    sal: 9900
  },
  {
    _id: ObjectId('696bc3f825b9d854a11e2622'),
    ename: 'Sai',
    empid: 107,
    sal: 8000
  },
  { _id: 300, ename: 'Ramu', sal: 10000 }
]
test> DBQuery.displayBatchSize=2
2
test> db.emp.find()
[
  {
    _id: ObjectId('694e86da48b36af6011e2623'),
    ename: 'cvbnm',
    empid: 99,
    sal: 9000
  },
  {
    _id: ObjectId('694e887448b36af6011e2624'),
    ename: 'ijhg',
    empid: 978,
    sal: 9800
  },
  {
    _id: ObjectId('694e887448b36af6011e2625'),
    ename: 'uytrsdfgh',
    empid: 97,
    sal: 5000
  },
  {
    _id: ObjectId('694e887448b36af6011e2626'),
    ename: 'thannu',
    empid: 37,
    sal: 2000
  },
  {
    _id: ObjectId('694e896c48b36af6011e2627'),
    ename: 'bbb',
    empid: 0,
    sal: 10
  },
  {
    _id: ObjectId('694e89ca48b36af6011e2628'),
    ename: 'iuytrsgh',
    empid: 39999,
    sal: 899
  },
  {
    _id: ObjectId('694e8b3548b36af6011e2629'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b4d48b36af6011e262a'),
    ename: 'krishna',
    sal: 3222,
    empid: 99
  },
  {
    _id: ObjectId('694e8b8248b36af6011e262b'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b8448b36af6011e262c'),
    ename: 'krishna',
    sal: 3222,
    _empid: 99
  },
  {
    _id: ObjectId('694e8b9448b36af6011e262d'),
    ename: 'krishna',
    sal: 22,
    _empid: 99
  },
  { _id: 99, ename: 'krishna', sal: 22 },
  {
    _id: ObjectId('694e8f6048b36af6011e262e'),
    ename: 'john',
    empid: 101,
    sal: 9000
  },
  {
    _id: ObjectId('694e8f6048b36af6011e262f'),
    ename: 'jane',
    empid: 102,
    sal: 9500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2630'),
    ename: 'doe',
    empid: 103,
    sal: 8500
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2631'),
    ename: 'smith',
    empid: 104,
    sal: 9200
  },
  {
    _id: ObjectId('694e8f6048b36af6011e2632'),
    ename: 'alice',
    empid: 105,
    sal: 9800
  },
  {
    _id: ObjectId('696bc3b425b9d854a11e2621'),
    ename: 'Ravi',
    empid: 106,
    sal: 9900
  },
  {
    _id: ObjectId('696bc3f825b9d854a11e2622'),
    ename: 'Sai',
    empid: 107,
    sal: 8000
  },
  { _id: 300, ename: 'Ramu', sal: 10000 }
]
test> db.emp.find().count()
20
test>
