# %% [markdown]
# <a href="https://colab.research.google.com/github/thanmai09/mongodb-commands/blob/main/insertcommands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(base) C:\Users\LENOVO>mongoimport --version
'mongoimport' is not recognized as an internal or external command,
operable program or batch file.

(base) C:\Users\LENOVO>cd C:\Program Files\MongoDB\Server\7.0

(base) C:\Program Files\MongoDB\Server\7.0>mongoimport --db test --collection employees --file "C:\Users\LENOVO\OneDrive\Desktop\js\data.json" --jsonArray
2025-12-26T19:54:45.864+0530    connected to: mongodb://localhost/
2025-12-26T19:54:45.894+0530    3 document(s) imported successfully. 0 document(s) failed to import.

(base) C:\Program Files\MongoDB\Server\7.0>
