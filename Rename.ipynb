# %% [markdown]
# <a href="https://colab.research.google.com/github/thanmai09/mongodb-commands/blob/main/Rename.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Microsoft Windows [Version 10.0.19045.6466]
(c) Microsoft Corporation. All rights reserved.

C:\Users\LENOVO>mongod
{"t":{"$date":"2026-01-12T22:37:40.242+05:30"},"s":"I",  "c":"CONTROL",  "id":23285,   "ctx":"thread1","msg":"Automatically disabling TLS 1.0, to force-enable TLS 1.0 specify --sslDisabledProtocols 'none'"}
{"t":{"$date":"2026-01-12T22:37:40.257+05:30"},"s":"I",  "c":"NETWORK",  "id":4915701, "ctx":"thread1","msg":"Initialized wire specification","attr":{"spec":{"incomingExternalClient":{"minWireVersion":0,"maxWireVersion":21},"incomingInternalClient":{"minWireVersion":0,"maxWireVersion":21},"outgoing":{"minWireVersion":6,"maxWireVersion":21},"isInternalClient":true}}}
{"t":{"$date":"2026-01-12T22:37:40.283+05:30"},"s":"I",  "c":"NETWORK",  "id":4648602, "ctx":"thread1","msg":"Implicit TCP FastOpen in use."}
{"t":{"$date":"2026-01-12T22:37:40.333+05:30"},"s":"I",  "c":"REPL",     "id":5123008, "ctx":"thread1","msg":"Successfully registered PrimaryOnlyService","attr":{"service":"TenantMigrationDonorService","namespace":"config.tenantMigrationDonors"}}
{"t":{"$date":"2026-01-12T22:37:40.334+05:30"},"s":"I",  "c":"REPL",     "id":5123008, "ctx":"thread1","msg":"Successfully registered PrimaryOnlyService","attr":{"service":"TenantMigrationRecipientService","namespace":"config.tenantMigrationRecipients"}}
{"t":{"$date":"2026-01-12T22:37:40.335+05:30"},"s":"I",  "c":"CONTROL",  "id":5945603, "ctx":"thread1","msg":"Multi threading initialized"}
{"t":{"$date":"2026-01-12T22:37:40.336+05:30"},"s":"I",  "c":"TENANT_M", "id":7091600, "ctx":"thread1","msg":"Starting TenantMigrationAccessBlockerRegistry"}
{"t":{"$date":"2026-01-12T22:37:40.337+05:30"},"s":"I",  "c":"CONTROL",  "id":4615611, "ctx":"initandlisten","msg":"MongoDB starting","attr":{"pid":10300,"port":27017,"dbPath":"C:/data/db/","architecture":"64-bit","host":"DESKTOP-M7L5VQ3"}}
{"t":{"$date":"2026-01-12T22:37:40.338+05:30"},"s":"I",  "c":"CONTROL",  "id":23398,   "ctx":"initandlisten","msg":"Target operating system minimum version","attr":{"targetMinOS":"Windows 7/Windows Server 2008 R2"}}
{"t":{"$date":"2026-01-12T22:37:40.338+05:30"},"s":"I",  "c":"CONTROL",  "id":23403,   "ctx":"initandlisten","msg":"Build Info","attr":{"buildInfo":{"version":"7.0.28","gitVersion":"cfc346c59d2cc3dbc903507fc642e22e3097f362","modules":[],"allocator":"tcmalloc","environment":{"distmod":"windows","distarch":"x86_64","target_arch":"x86_64"}}}}
{"t":{"$date":"2026-01-12T22:37:40.338+05:30"},"s":"I",  "c":"CONTROL",  "id":51765,   "ctx":"initandlisten","msg":"Operating System","attr":{"os":{"name":"Microsoft Windows 10","version":"10.0 (build 19045)"}}}
{"t":{"$date":"2026-01-12T22:37:40.339+05:30"},"s":"I",  "c":"CONTROL",  "id":21951,   "ctx":"initandlisten","msg":"Options set by command line","attr":{"options":{}}}
{"t":{"$date":"2026-01-12T22:37:40.347+05:30"},"s":"E",  "c":"CONTROL",  "id":20557,   "ctx":"initandlisten","msg":"DBException in initAndListen, terminating","attr":{"error":"NonExistentPath: Data directory C:\\data\\db\\ not found. Create the missing directory or specify another path using (1) the --dbpath command line option, or (2) by adding the 'storage.dbPath' option in the configuration file."}}
{"t":{"$date":"2026-01-12T22:37:40.354+05:30"},"s":"I",  "c":"REPL",     "id":4784900, "ctx":"initandlisten","msg":"Stepping down the ReplicationCoordinator for shutdown","attr":{"waitTimeMillis":15000}}
{"t":{"$date":"2026-01-12T22:37:40.359+05:30"},"s":"I",  "c":"REPL",     "id":4794602, "ctx":"initandlisten","msg":"Attempting to enter quiesce mode"}
{"t":{"$date":"2026-01-12T22:37:40.360+05:30"},"s":"I",  "c":"-",        "id":6371601, "ctx":"initandlisten","msg":"Shutting down the FLE Crud thread pool"}
{"t":{"$date":"2026-01-12T22:37:40.360+05:30"},"s":"I",  "c":"COMMAND",  "id":4784901, "ctx":"initandlisten","msg":"Shutting down the MirrorMaestro"}
{"t":{"$date":"2026-01-12T22:37:40.361+05:30"},"s":"I",  "c":"SHARDING", "id":4784902, "ctx":"initandlisten","msg":"Shutting down the WaitForMajorityService"}
{"t":{"$date":"2026-01-12T22:37:40.362+05:30"},"s":"I",  "c":"NETWORK",  "id":20562,   "ctx":"initandlisten","msg":"Shutdown: going to close listening sockets"}
{"t":{"$date":"2026-01-12T22:37:40.362+05:30"},"s":"I",  "c":"NETWORK",  "id":4784905, "ctx":"initandlisten","msg":"Shutting down the global connection pool"}
{"t":{"$date":"2026-01-12T22:37:40.363+05:30"},"s":"I",  "c":"CONTROL",  "id":4784906, "ctx":"initandlisten","msg":"Shutting down the FlowControlTicketholder"}
{"t":{"$date":"2026-01-12T22:37:40.368+05:30"},"s":"I",  "c":"-",        "id":20520,   "ctx":"initandlisten","msg":"Stopping further Flow Control ticket acquisitions."}
{"t":{"$date":"2026-01-12T22:37:40.369+05:30"},"s":"I",  "c":"NETWORK",  "id":4784918, "ctx":"initandlisten","msg":"Shutting down the ReplicaSetMonitor"}
{"t":{"$date":"2026-01-12T22:37:40.369+05:30"},"s":"I",  "c":"SHARDING", "id":4784921, "ctx":"initandlisten","msg":"Shutting down the MigrationUtilExecutor"}
{"t":{"$date":"2026-01-12T22:37:40.371+05:30"},"s":"I",  "c":"ASIO",     "id":22582,   "ctx":"MigrationUtil-TaskExecutor","msg":"Killing all outstanding egress activity."}
{"t":{"$date":"2026-01-12T22:37:40.373+05:30"},"s":"I",  "c":"COMMAND",  "id":4784923, "ctx":"initandlisten","msg":"Shutting down the ServiceEntryPoint"}
{"t":{"$date":"2026-01-12T22:37:40.373+05:30"},"s":"I",  "c":"CONTROL",  "id":4784928, "ctx":"initandlisten","msg":"Shutting down the TTL monitor"}
{"t":{"$date":"2026-01-12T22:37:40.374+05:30"},"s":"I",  "c":"CONTROL",  "id":6278511, "ctx":"initandlisten","msg":"Shutting down the Change Stream Expired Pre-images Remover"}
{"t":{"$date":"2026-01-12T22:37:40.374+05:30"},"s":"I",  "c":"CONTROL",  "id":4784929, "ctx":"initandlisten","msg":"Acquiring the global lock for shutdown"}
{"t":{"$date":"2026-01-12T22:37:40.376+05:30"},"s":"I",  "c":"-",        "id":4784931, "ctx":"initandlisten","msg":"Dropping the scope cache for shutdown"}
{"t":{"$date":"2026-01-12T22:37:40.378+05:30"},"s":"I",  "c":"CONTROL",  "id":20565,   "ctx":"initandlisten","msg":"Now exiting"}
{"t":{"$date":"2026-01-12T22:37:40.382+05:30"},"s":"I",  "c":"CONTROL",  "id":8423404, "ctx":"initandlisten","msg":"mongod shutdown complete","attr":{"Summary of time elapsed":{"Statistics":{"Enter terminal shutdown":"0 ms","Step down the replication coordinator for shutdown":"12 ms","Time spent in quiesce mode":"0 ms","Shut down FLE Crud subsystem":"1 ms","Shut down MirrorMaestro":"0 ms","Shut down WaitForMajorityService":"1 ms","Shut down the transport layer":"1 ms","Shut down the global connection pool":"0 ms","Shut down the flow control ticket holder":"6 ms","Shut down the replica set monitor":"1 ms","Shut down the migration util executor":"2 ms","Shut down the TTL monitor":"0 ms","Shut down expired pre-images and documents removers":"1 ms","Wait for the oplog cap maintainer thread to stop":"0 ms","Shut down full-time data capture":"0 ms","shutdownTask total elapsed time":"31 ms"}}}}
{"t":{"$date":"2026-01-12T22:37:40.383+05:30"},"s":"I",  "c":"CONTROL",  "id":23138,   "ctx":"initandlisten","msg":"Shutting down","attr":{"exitCode":100}}

C:\Users\LENOVO>mongosh
Current Mongosh Log ID: 69652a6c4a4ff76ec31e2620
Connecting to:          mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.5.10
Using MongoDB:          7.0.28
Using Mongosh:          2.5.10

For mongosh info see: https://www.mongodb.com/docs/mongodb-shell/

------
   The server generated these startup warnings when booting
   2026-01-03T12:40:57.564+05:30: Access control is not enabled for the database. Read and write access to data and configuration is unrestricted
------

test> show dbs
admin       40.00 KiB
config      96.00 KiB
employees  112.00 KiB
local       72.00 KiB
test       112.00 KiB
test> use employees
switched to db employees
employees> db.emp.find()
[
  {
    _id: ObjectId('694d0b53d53b3b43f01e2621'),
    ename: 'abc',
    empid: 1234
  },
  {
    _id: ObjectId('694d0c32d53b3b43f01e2622'),
    ename: 'xyz',
    empid: 9876,
    sal: 92000
  },
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 100000000
  },
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    name: 'mummy',
    sal: 900000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 9196,
    sal: 78000
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd585d8926b7d2d1e2621')
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd5e1d8926b7d2d1e2622')
  }
]
employees> db.emp.updateOne({ename:"nani"},{$nul:{sal:2}})
MongoServerError: Unknown modifier: $nul. Expected a valid update modifier or pipeline-style update specified as an array
employees> db.emp.updateOne({ename:"nani"},{$mul:{sal:2}})
{
  acknowledged: true,
  insertedId: null,
  matchedCount: 1,
  modifiedCount: 1,
  upsertedCount: 0
}
employees> db.emp.find()
[
  {
    _id: ObjectId('694d0b53d53b3b43f01e2621'),
    ename: 'abc',
    empid: 1234
  },
  {
    _id: ObjectId('694d0c32d53b3b43f01e2622'),
    ename: 'xyz',
    empid: 9876,
    sal: 92000
  },
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 100000000
  },
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    name: 'mummy',
    sal: 900000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 9196,
    sal: 156000
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd585d8926b7d2d1e2621')
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd5e1d8926b7d2d1e2622')
  }
]
employees> db.emp.updateOne({},{$rename:{ename:"name"}})
{
  acknowledged: true,
  insertedId: null,
  matchedCount: 1,
  modifiedCount: 1,
  upsertedCount: 0
}
employees> db.emp.find()
[
  {
    _id: ObjectId('694d0b53d53b3b43f01e2621'),
    empid: 1234,
    name: 'abc'
  },
  {
    _id: ObjectId('694d0c32d53b3b43f01e2622'),
    ename: 'xyz',
    empid: 9876,
    sal: 92000
  },
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 100000000
  },
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    name: 'mummy',
    sal: 900000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 9196,
    sal: 156000
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd585d8926b7d2d1e2621')
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd5e1d8926b7d2d1e2622')
  }
]
employees>
