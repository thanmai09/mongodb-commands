# %% [markdown]
# <a href="https://colab.research.google.com/github/thanmai09/mongodb-commands/blob/main/Pagination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Microsoft Windows [Version 10.0.19045.6466]
(c) Microsoft Corporation. All rights reserved.

C:\Users\LENOVO>mongod
{"t":{"$date":"2026-01-09T12:09:07.354+05:30"},"s":"I",  "c":"CONTROL",  "id":23285,   "ctx":"thread1","msg":"Automatically disabling TLS 1.0, to force-enable TLS 1.0 specify --sslDisabledProtocols 'none'"}
{"t":{"$date":"2026-01-09T12:09:07.373+05:30"},"s":"I",  "c":"NETWORK",  "id":4915701, "ctx":"thread1","msg":"Initialized wire specification","attr":{"spec":{"incomingExternalClient":{"minWireVersion":0,"maxWireVersion":21},"incomingInternalClient":{"minWireVersion":0,"maxWireVersion":21},"outgoing":{"minWireVersion":6,"maxWireVersion":21},"isInternalClient":true}}}
{"t":{"$date":"2026-01-09T12:09:07.398+05:30"},"s":"I",  "c":"NETWORK",  "id":4648602, "ctx":"thread1","msg":"Implicit TCP FastOpen in use."}
{"t":{"$date":"2026-01-09T12:09:07.454+05:30"},"s":"I",  "c":"REPL",     "id":5123008, "ctx":"thread1","msg":"Successfully registered PrimaryOnlyService","attr":{"service":"TenantMigrationDonorService","namespace":"config.tenantMigrationDonors"}}
{"t":{"$date":"2026-01-09T12:09:07.454+05:30"},"s":"I",  "c":"REPL",     "id":5123008, "ctx":"thread1","msg":"Successfully registered PrimaryOnlyService","attr":{"service":"TenantMigrationRecipientService","namespace":"config.tenantMigrationRecipients"}}
{"t":{"$date":"2026-01-09T12:09:07.462+05:30"},"s":"I",  "c":"CONTROL",  "id":5945603, "ctx":"thread1","msg":"Multi threading initialized"}
{"t":{"$date":"2026-01-09T12:09:07.463+05:30"},"s":"I",  "c":"TENANT_M", "id":7091600, "ctx":"thread1","msg":"Starting TenantMigrationAccessBlockerRegistry"}
{"t":{"$date":"2026-01-09T12:09:07.497+05:30"},"s":"I",  "c":"CONTROL",  "id":4615611, "ctx":"initandlisten","msg":"MongoDB starting","attr":{"pid":13372,"port":27017,"dbPath":"C:/data/db/","architecture":"64-bit","host":"DESKTOP-M7L5VQ3"}}
{"t":{"$date":"2026-01-09T12:09:07.498+05:30"},"s":"I",  "c":"CONTROL",  "id":23398,   "ctx":"initandlisten","msg":"Target operating system minimum version","attr":{"targetMinOS":"Windows 7/Windows Server 2008 R2"}}
{"t":{"$date":"2026-01-09T12:09:07.499+05:30"},"s":"I",  "c":"CONTROL",  "id":23403,   "ctx":"initandlisten","msg":"Build Info","attr":{"buildInfo":{"version":"7.0.28","gitVersion":"cfc346c59d2cc3dbc903507fc642e22e3097f362","modules":[],"allocator":"tcmalloc","environment":{"distmod":"windows","distarch":"x86_64","target_arch":"x86_64"}}}}
{"t":{"$date":"2026-01-09T12:09:07.499+05:30"},"s":"I",  "c":"CONTROL",  "id":51765,   "ctx":"initandlisten","msg":"Operating System","attr":{"os":{"name":"Microsoft Windows 10","version":"10.0 (build 19045)"}}}
{"t":{"$date":"2026-01-09T12:09:07.505+05:30"},"s":"I",  "c":"CONTROL",  "id":21951,   "ctx":"initandlisten","msg":"Options set by command line","attr":{"options":{}}}
{"t":{"$date":"2026-01-09T12:09:07.536+05:30"},"s":"E",  "c":"CONTROL",  "id":20557,   "ctx":"initandlisten","msg":"DBException in initAndListen, terminating","attr":{"error":"NonExistentPath: Data directory C:\\data\\db\\ not found. Create the missing directory or specify another path using (1) the --dbpath command line option, or (2) by adding the 'storage.dbPath' option in the configuration file."}}
{"t":{"$date":"2026-01-09T12:09:07.540+05:30"},"s":"I",  "c":"REPL",     "id":4784900, "ctx":"initandlisten","msg":"Stepping down the ReplicationCoordinator for shutdown","attr":{"waitTimeMillis":15000}}
{"t":{"$date":"2026-01-09T12:09:07.553+05:30"},"s":"I",  "c":"REPL",     "id":4794602, "ctx":"initandlisten","msg":"Attempting to enter quiesce mode"}
{"t":{"$date":"2026-01-09T12:09:07.559+05:30"},"s":"I",  "c":"-",        "id":6371601, "ctx":"initandlisten","msg":"Shutting down the FLE Crud thread pool"}
{"t":{"$date":"2026-01-09T12:09:07.559+05:30"},"s":"I",  "c":"COMMAND",  "id":4784901, "ctx":"initandlisten","msg":"Shutting down the MirrorMaestro"}
{"t":{"$date":"2026-01-09T12:09:07.560+05:30"},"s":"I",  "c":"SHARDING", "id":4784902, "ctx":"initandlisten","msg":"Shutting down the WaitForMajorityService"}
{"t":{"$date":"2026-01-09T12:09:07.563+05:30"},"s":"I",  "c":"NETWORK",  "id":20562,   "ctx":"initandlisten","msg":"Shutdown: going to close listening sockets"}
{"t":{"$date":"2026-01-09T12:09:07.584+05:30"},"s":"I",  "c":"NETWORK",  "id":4784905, "ctx":"initandlisten","msg":"Shutting down the global connection pool"}
{"t":{"$date":"2026-01-09T12:09:07.590+05:30"},"s":"I",  "c":"CONTROL",  "id":4784906, "ctx":"initandlisten","msg":"Shutting down the FlowControlTicketholder"}
{"t":{"$date":"2026-01-09T12:09:07.592+05:30"},"s":"I",  "c":"-",        "id":20520,   "ctx":"initandlisten","msg":"Stopping further Flow Control ticket acquisitions."}
{"t":{"$date":"2026-01-09T12:09:07.598+05:30"},"s":"I",  "c":"NETWORK",  "id":4784918, "ctx":"initandlisten","msg":"Shutting down the ReplicaSetMonitor"}
{"t":{"$date":"2026-01-09T12:09:07.598+05:30"},"s":"I",  "c":"SHARDING", "id":4784921, "ctx":"initandlisten","msg":"Shutting down the MigrationUtilExecutor"}
{"t":{"$date":"2026-01-09T12:09:07.605+05:30"},"s":"I",  "c":"ASIO",     "id":22582,   "ctx":"MigrationUtil-TaskExecutor","msg":"Killing all outstanding egress activity."}
{"t":{"$date":"2026-01-09T12:09:07.608+05:30"},"s":"I",  "c":"COMMAND",  "id":4784923, "ctx":"initandlisten","msg":"Shutting down the ServiceEntryPoint"}
{"t":{"$date":"2026-01-09T12:09:07.608+05:30"},"s":"I",  "c":"CONTROL",  "id":4784928, "ctx":"initandlisten","msg":"Shutting down the TTL monitor"}
{"t":{"$date":"2026-01-09T12:09:07.609+05:30"},"s":"I",  "c":"CONTROL",  "id":6278511, "ctx":"initandlisten","msg":"Shutting down the Change Stream Expired Pre-images Remover"}
{"t":{"$date":"2026-01-09T12:09:07.610+05:30"},"s":"I",  "c":"CONTROL",  "id":4784929, "ctx":"initandlisten","msg":"Acquiring the global lock for shutdown"}
{"t":{"$date":"2026-01-09T12:09:07.615+05:30"},"s":"I",  "c":"-",        "id":4784931, "ctx":"initandlisten","msg":"Dropping the scope cache for shutdown"}
{"t":{"$date":"2026-01-09T12:09:07.618+05:30"},"s":"I",  "c":"CONTROL",  "id":20565,   "ctx":"initandlisten","msg":"Now exiting"}
{"t":{"$date":"2026-01-09T12:09:07.620+05:30"},"s":"I",  "c":"CONTROL",  "id":8423404, "ctx":"initandlisten","msg":"mongod shutdown complete","attr":{"Summary of time elapsed":{"Statistics":{"Enter terminal shutdown":"0 ms","Step down the replication coordinator for shutdown":"17 ms","Time spent in quiesce mode":"0 ms","Shut down FLE Crud subsystem":"6 ms","Shut down MirrorMaestro":"0 ms","Shut down WaitForMajorityService":"1 ms","Shut down the transport layer":"24 ms","Shut down the global connection pool":"0 ms","Shut down the flow control ticket holder":"11 ms","Shut down the replica set monitor":"3 ms","Shut down the migration util executor":"8 ms","Shut down the TTL monitor":"0 ms","Shut down expired pre-images and documents removers":"1 ms","Wait for the oplog cap maintainer thread to stop":"0 ms","Shut down full-time data capture":"0 ms","shutdownTask total elapsed time":"82 ms"}}}}
{"t":{"$date":"2026-01-09T12:09:07.622+05:30"},"s":"I",  "c":"CONTROL",  "id":23138,   "ctx":"initandlisten","msg":"Shutting down","attr":{"exitCode":100}}

C:\Users\LENOVO>mongosh
Current Mongosh Log ID: 6960a296a15ce6cebc1e2620
Connecting to:          mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.5.10
Using MongoDB:          7.0.28
Using Mongosh:          2.5.10

For mongosh info see: https://www.mongodb.com/docs/mongodb-shell/

------
   The server generated these startup warnings when booting
   2026-01-03T12:40:57.564+05:30: Access control is not enabled for the database. Read and write access to data and configuration is unrestricted
------

test> show dbs
admin       40.00 KiB
config      96.00 KiB
employees  112.00 KiB
local       72.00 KiB
test       112.00 KiB
test> use employees
switched to db employees
employees> db.emp.find()
[
  {
    _id: ObjectId('694d0b53d53b3b43f01e2621'),
    ename: 'abc',
    empid: 1234,
    sal: 6000
  },
  {
    _id: ObjectId('694d0c32d53b3b43f01e2622'),
    ename: 'xyz',
    empid: 9876,
    sal: 90000
  },
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 90000
  },
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    ename: 'pavani',
    empid: 3789,
    sal: 7000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 319,
    sal: 78000
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd585d8926b7d2d1e2621')
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd5e1d8926b7d2d1e2622')
  }
]
employees> db.emp.find().limit(3)
[
  {
    _id: ObjectId('694d0b53d53b3b43f01e2621'),
    ename: 'abc',
    empid: 1234,
    sal: 6000
  },
  {
    _id: ObjectId('694d0c32d53b3b43f01e2622'),
    ename: 'xyz',
    empid: 9876,
    sal: 90000
  },
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 90000
  }
]
employees> db.emp.find().limit(3).skip(3)
[
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    ename: 'pavani',
    empid: 3789,
    sal: 7000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 319,
    sal: 78000
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd585d8926b7d2d1e2621')
  }
]
employees> const empPerPage = 3;

employees> empPerPage
3
employees> db.emp.find().limit(empPerPage)
[
  {
    _id: ObjectId('694d0b53d53b3b43f01e2621'),
    ename: 'abc',
    empid: 1234,
    sal: 6000
  },
  {
    _id: ObjectId('694d0c32d53b3b43f01e2622'),
    ename: 'xyz',
    empid: 9876,
    sal: 90000
  },
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 90000
  }
]
employees> let currPage = 1;

employees> currPage
1
employees> db.emp.find().limit(empPerPage).skip((currPage - 1)^empPerPage)
[
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    ename: 'pavani',
    empid: 3789,
    sal: 7000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 319,
    sal: 78000
  },
  {
    '0': 'd',
    '1': 'h',
    '2': 'a',
    '3': 'r',
    '4': 'a',
    '5': 'n',
    '6': 'i',
    _id: ObjectId('695bd585d8926b7d2d1e2621')
  }
]
employees> let currPage = 2

employees> currPage
2
employees> db.emp.find().limit(empPerPage).skip((currPage - 1)^empPerPage)
[
  {
    _id: ObjectId('6952a1edc8c56c09791e2621'),
    ename: 'thanmai',
    empid: 789,
    sal: 90000
  },
  {
    _id: ObjectId('6952a20fc8c56c09791e2622'),
    ename: 'pavani',
    empid: 3789,
    sal: 7000
  },
  {
    _id: ObjectId('6952a233c8c56c09791e2623'),
    ename: 'nani',
    empid: 319,
    sal: 78000
  }
]
employees>
